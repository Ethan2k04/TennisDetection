# %%
import uuid
import os

# %%
pid = os.getpid()
pid
# Out:
# 59002

# %%
ppid = os.getppid()
ppid
# Out:
# 74696

# %%
env = os.getenv('PATH')
env
# Out:
# '/Users/yintao/Documents/python-tenis/TennisDetection/venv/bin:/Users/yintao/google-cloud-sdk/bin:/Users/yintao/perl5/bin:/Users/yintao/anaconda3/bin:/Users/yintao/anaconda3/condabin:/opt/homebrew/bin:/opt/homebrew/sbin:/usr/local/bin:/System/Cryptexes/App/usr/bin:/usr/bin:/bin:/usr/sbin:/sbin:/var/run/com.apple.security.cryptexd/codex.system/bootstrap/usr/local/bin:/var/run/com.apple.security.cryptexd/codex.system/bootstrap/usr/bin:/var/run/com.apple.security.cryptexd/codex.system/bootstrap/usr/appleinternal/bin:/Library/Apple/usr/bin:/Users/yintao/.cargo/bin'

# %%
mac = uuid.getnode()

# %%
targets = {}

# %%
type(targets)
# Out:
# dict

# %%
len(targets)
# Out:
# 0

# %%
hex(mac)
# Out:
# '0xb26dc93ece0f'

# %%
f = list(*'mp4v')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 f = list(*'mp4v')
#
# TypeError: list expected at most 1 argument, got 4
