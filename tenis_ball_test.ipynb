# %%
import uuid
import os

# %%
pid = os.getpid()
pid
# Out:
# 59002

# %%
ppid = os.getppid()
ppid
# Out:
# 58392

# %%
env = os.getenv('PATH')
env
# Out:
# '/Users/yintao/Documents/python-tenis/TennisDetection/venv/bin:/Users/yintao/google-cloud-sdk/bin:/Users/yintao/perl5/bin:/Users/yintao/anaconda3/bin:/Users/yintao/anaconda3/condabin:/usr/local/bin:/System/Cryptexes/App/usr/bin:/usr/bin:/bin:/usr/sbin:/sbin:/var/run/com.apple.security.cryptexd/codex.system/bootstrap/usr/local/bin:/var/run/com.apple.security.cryptexd/codex.system/bootstrap/usr/bin:/var/run/com.apple.security.cryptexd/codex.system/bootstrap/usr/appleinternal/bin:/Library/Apple/usr/bin:/Users/yintao/.cargo/bin'

# %%
mac = uuid.getnode()

# %%
hex(mac)
# Out:
# '0xb26dc93ece0f'
